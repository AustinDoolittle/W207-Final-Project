# %% [markdown]
# # Zillow Housing Pricing

# %% [markdown]
# ## Required Packages

# %%
import pandas

# %% [markdown]
# ## EDA
# Read the data into memory

# %%
props = pandas.read_csv('./data/properties_2016.csv')
# properties2017 = pandas.read_csv('./data/properties_2017.csv')
# Out:
# /home/austin/.conda/envs/r_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Take a peek

# %%
props.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# ...

# %% [markdown]
# ### Cleaning
# It appears that there are NaN values sprinkled through the dataset. Based on the codebook, it looks like this is split into either not having a specific feature or just missing data.
#
# An example of the first case is the `airconditionigtypeid` which has a value `NaN` when there is not air conditioning in the house. We don't want to remove all instances of no air conditioning as that will effect our final classification. Instead, we will treat these as categorical variables and use dummy variables for each categorical value. These columns are assumed to be those in the codebook that have the "(if any)" qualifier in their description.
#
# The second case just deals with missing values. In the below code, we can check if we have any instances of a complete row excluding the columns that us NaN as a category.

# %%
# These are the columns where NaNs are considered a category and should not be removed
no_remove_nans = set(['airconditioningtypeid', 'decktypeid', 'fireplacecnt', 'poolcnt', 'regionidcity'])

# get the remaining columns
remove_nans = set(props.columns) - no_remove_nans

# check if there are any columns that have a complete row
(~props[remove_nans].isna().any('columns')).any()
# Out:
# False

# %% [markdown]
# It would appear that there is no complete row of data in the bunch. We will have to replace those values to get a semi-decent classifier. Note that we can't interpolate categorical/ordinal data. Let's handle oridinal data, then categorical data, and finally remove NaNs from the remaining data

# %%
ordinal_variables = ['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', \
                     'threequarterbathnbr', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', \
                     'numberofstories', 'poolcnt', 'unitcnt']

# remove rows from here that have NaNs
# props[ordinal_variables]
# print(props.shape)
# props1 = props[~(props[ordinal_variables].isna()).any('columns')]
# print(props1.shape)

# %% [markdown]
# Screw that, let's try building a simple classifier with subset of features

# %%
trans = pandas.read_csv('./data/train_2016_v2.csv')

# %%
trans_ss = trans[trans['transactiondate'].str.startswith('2016-12')].drop_duplicates('parcelid')
props_ss = props[]
# Out:
#        parcelid  logerror transactiondate
# 3421   13923841    0.0090      2016-12-28
# 10829  10736972   -0.0367      2016-12-14
# 10941  11663348    0.0751      2016-12-05
# 12731  11913710    0.1621      2016-12-13
# 14707  11061551    0.0421      2016-12-20
# 17031  10821829    0.1371      2016-12-30
# 32222  14500952    0.0030      2016-12-22
# 32357  14621246    0.0159      2016-12-07
# 36884  11729067   -0.3581      2016-12-22
# 42035  11822007    0.0440      2016-12-08
# 43924  14141531   -0.0481      2016-12-28
# 74547  11419032   -0.0040      2016-12-29
# 88548  11084105    0.0411      2016-12-01
# 88549  14719380    0.0469      2016-12-01
# 88550  17251362   -0.0367      2016-12-01
# 88551  12687731    0.0050      2016-12-01
# 88552  14724205    0.1035      2016-12-01
# 88553  12160093    0.4713      2016-12-01
# 88554  11120340    0.0450      2016-12-01
# 88555  17234685   -0.0050      2016-12-01
# 88556  11037315   -0.0192      2016-12-01
# ...
